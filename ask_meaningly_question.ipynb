# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv('data.csv')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30360 entries, 0 to 30359
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 9144 non-null   object
#  1   Price                 30360 non-null  object
#  2   Address               30360 non-null  object
#  3   Price per m2          12 non-null     object
#  4   Area                  30358 non-null  object
#  5   Bedrooms              20632 non-null  object
#  6   Toilets               19720 non-null  object
#  7   Published At          30360 non-null  object
#  8   Diện tích             30358 non-null  object
#  9   Mức giá               30360 non-null  object
#  10  Hướng nhà             7640 non-null   object
#  11  Hướng ban công        4677 non-null   object
#  12  Ngày đăng             30360 non-null  object
#  13  Ngày hết hạn          30360 non-null  object
#  14  Loại tin              30360 non-null  object
#  15  Mã tin                30360 non-null  object
#  16  Project Title         9144 non-null   object
#  17  Status                9144 non-null   object
#  18  Number of Apartments  9144 non-null   object
#  19  Number of Buildings   6171 non-null   object
#  20  Developer             9144 non-null   object
#  21  Project Address       30360 non-null  object
# dtypes: object(22)
# memory usage: 5.1+ MB

# %%
unduplicated_data = raw_data.drop_duplicates(subset=['Mã tin'], keep='first')
unduplicated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12446 entries, 0 to 30359
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 3838 non-null   object
#  1   Price                 12446 non-null  object
#  2   Address               12446 non-null  object
#  3   Price per m2          1 non-null      object
#  4   Area                  12445 non-null  object
#  5   Bedrooms              8202 non-null   object
#  6   Toilets               7805 non-null   object
#  7   Published At          12446 non-null  object
#  8   Diện tích             12445 non-null  object
#  9   Mức giá               12446 non-null  object
#  10  Hướng nhà             3131 non-null   object
#  11  Hướng ban công        1828 non-null   object
#  12  Ngày đăng             12446 non-null  object
#  13  Ngày hết hạn          12446 non-null  object
#  14  Loại tin              12446 non-null  object
#  15  Mã tin                12446 non-null  object
#  16  Project Title         3838 non-null   object
#  17  Status                3838 non-null   object
#  18  Number of Apartments  3838 non-null   object
#  19  Number of Buildings   2578 non-null   object
#  20  Developer             3838 non-null   object
#  21  Project Address       12446 non-null  object
# dtypes: object(22)
# memory usage: 2.2+ MB

# %%
unduplicated_data = unduplicated_data.drop(["Price per m2","Project Address", "Title", "Diện tích", "Mức giá", "Project Title", "Ngày hết hạn", "Number of Buildings", "Ngày đăng", "Mã tin"], axis="columns")
unduplicated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12446 entries, 0 to 30359
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Price                 12446 non-null  object
#  1   Address               12446 non-null  object
#  2   Area                  12445 non-null  object
#  3   Bedrooms              8202 non-null   object
#  4   Toilets               7805 non-null   object
#  5   Published At          12446 non-null  object
#  6   Hướng nhà             3131 non-null   object
#  7   Hướng ban công        1828 non-null   object
#  8   Loại tin              12446 non-null  object
#  9   Status                3838 non-null   object
#  10  Number of Apartments  3838 non-null   object
#  11  Developer             3838 non-null   object
# dtypes: object(12)
# memory usage: 1.2+ MB

# %%
# unduplicated_data_2.head(30)
unduplicated_data = unduplicated_data[unduplicated_data["Price"] != "Thỏa thuận"]
unduplicated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11508 entries, 0 to 30359
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Price                 11508 non-null  object
#  1   Address               11508 non-null  object
#  2   Area                  11507 non-null  object
#  3   Bedrooms              7567 non-null   object
#  4   Toilets               7208 non-null   object
#  5   Published At          11508 non-null  object
#  6   Hướng nhà             2957 non-null   object
#  7   Hướng ban công        1725 non-null   object
#  8   Loại tin              11508 non-null  object
#  9   Status                3606 non-null   object
#  10  Number of Apartments  3606 non-null   object
#  11  Developer             3606 non-null   object
# dtypes: object(12)
# memory usage: 1.1+ MB

# %%
unduplicated_data.head(10)
# Out:
#        Price                                            Address    Area  \
# 0    15,2 tỷ  Đường Dương Bá Trạc, Phường 2, Quận 8, Hồ Chí ...   40 m²
# 1     5,6 tỷ  Screc Tower, Đường Trường Sa, Phường 12, Quận ...   90 m²
# 2       7 tỷ  Dự án HaDo Centrosa Garden, Đường 3/2, Phường ...   87 m²
# 3   12,35 tỷ   Đường Nguyễn Trãi, Phường 7, Quận 5, Hồ Chí Minh   60 m²
# 5    1,35 tỷ  Dự án Dream Home Riverside, Đường Nguyễn Văn L...   57 m²
# 6     7,8 tỷ  Đường Phạm Văn Bạch, Phường 15, Tân Bình, Hồ C...  100 m²
# 7    5,95 tỷ  Dự án ICON 56, Đường Bến Vân Đồn, Phường 12, Q...   87 m²
# 9      16 tỷ           Phường Phước Long B, Quận 9, Hồ Chí Minh  156 m²
# 10    8,6 tỷ    Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh   34 m²
# 11    8,7 tỷ  Đường Huỳnh Tấn Phát, Phường Phú Thuận, Quận 7...   80 m²
#
#    Bedrooms  Toilets Published At Hướng nhà Hướng ban công           Loại tin  \
# 0   6 phòng  4 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 1   3 phòng  2 phòng   23/10/2024       NaN            NaN         Tin thường
# 2   2 phòng  2 phòng   23/10/2024       NaN            NaN  Tin VIP Kim Cương
# 3   4 phòng      NaN   22/10/2024       NaN            NaN         Tin thường
# 5   2 phòng  2 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 6   3 phòng  3 phòng   22/10/2024       NaN            NaN         Tin thường
# 7   3 phòng  2 phòng   15/10/2024       NaN            NaN         Tin thường
# 9   8 phòng  9 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 10  3 phòng  4 phòng   22/10/2024       NaN            NaN         Tin thường
# 11  4 phòng  5 phòng   04/10/2024       NaN            NaN         Tin thường
#
#          Status Number of Apartments  \
# 0           NaN                  NaN
# 1   đã bàn giao            60-106 m²
# 2   Đã bàn giao                2.178
# 3           NaN                  NaN
# 5   Đang mở bán             55-75 m²
# 6           NaN                  NaN
# 7   Đã bàn giao            47-112 m²
# 9           NaN                  NaN
# 10          NaN                  NaN
# 11          NaN                  NaN
#
#                                             Developer
# 0                                                 NaN
# 1   Công ty CP Đầu tư Xây dựng và Kinh doanh nhà S...
# 2                                      Tập đoàn Hà Đô
# 3                                                 NaN
# 5                        Công ty TNHH SX TM Lý Khương
# 6                                                 NaN
# 7                                      Novaland Group
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN

# %%
# Chuyển đổi dữ liệu ở cột Area sang float
def convert_area_value(value):
    try: 
        # Chỉ thực hiện thay thế nếu value là chuỗi
        if isinstance(value, str):
            # Lọc bỏ các dấu chấm ở số hàng nghìn
            value = value.replace('m²', '').replace('.', '')

            # Thay dấu phẩy thành dấu chấm
            value = value.replace(',', '.')
            
            return float(value)
        
        # Nếu value đã là số (float hoặc int), trả về trực tiếp
        elif isinstance(value, (int, float)):
            return float(value)

    except Exception as e:
        print(f"Lỗi khi xử lý giá trị: {value}. Chi tiết lỗi: {e}")
        return None

unduplicated_data['Diện Tích'] = unduplicated_data['Area'].apply(convert_area_value)
# Out:
# Lỗi khi xử lý giá trị: Area. Chi tiết lỗi: could not convert string to float: 'Area'

# %%
unduplicated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11508 entries, 0 to 30359
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Price                 11508 non-null  object
#  1   Address               11508 non-null  object
#  2   Area                  11507 non-null  object
#  3   Bedrooms              7567 non-null   object
#  4   Toilets               7208 non-null   object
#  5   Published At          11508 non-null  object
#  6   Hướng nhà             2957 non-null   object
#  7   Hướng ban công        1725 non-null   object
#  8   Loại tin              11508 non-null  object
#  9   Status                3606 non-null   object
#  10  Number of Apartments  3606 non-null   object
#  11  Developer             3606 non-null   object
#  12  Diện Tích             11506 non-null  float64
# dtypes: float64(1), object(12)
# memory usage: 1.2+ MB

# %%
# Hàm chuyển đổi giá trị thành tỷ với xử lý trường hợp "triệu/m²"
def convert_to_billion(value, area):
    try:
        # Chỉ thực hiện thay thế nếu value là chuỗi
        if isinstance(value, str):
            # Thay dấu phẩy thành dấu chấm
            value = value.replace(',', '.')

            # Dữ liệu chỉ đánh giá các bds rao bán nên sẽ không xử lý các bds cho thuê
            if '/tháng' in value:
                return None
            
            # Kiểm tra nếu có "triệu/m²"
            elif 'triệu/m²' in value:
                price_per_sqm = float(value.replace(' triệu/m²', '')) / 1000  # Đổi từ triệu/m² thành tỷ/m²
                return price_per_sqm * area  # Nhân với diện tích để có giá trị tổng

            # Kiểm tra nếu có "triệu/m²"
            elif 'tỷ/m²' in value:
                price_per_sqm = float(value.replace(' tỷ/m²', ''))
                return price_per_sqm * area  # Nhân với diện tích để có giá trị tổng

            # Xử lý các trường hợp có đơn vị "tỷ" hoặc "triệu"
            elif 'tỷ' in value:
                return float(value.replace(' tỷ', ''))
            
            # Chuyển "triệu" thành "tỷ"
            elif 'triệu' in value:
                return float(value.replace(' triệu', '')) / 1000  
        
        # Nếu value đã là số (float hoặc int), trả về trực tiếp
        elif isinstance(value, (int, float)):
            return float(value)
        
        return None
        
    except Exception as e:
        print(f"Lỗi khi xử lý giá trị: {value}. Chi tiết lỗi: {e}")
        return None

# Áp dụng hàm vào cột 'giá_cả' và truyền thêm cột 'diện_tích' để tính giá trị cuối cùng
unduplicated_data['Giá'] = unduplicated_data.apply(lambda row: convert_to_billion(row['Price'], row['Diện Tích']), axis=1)

# %%
unduplicated_data = unduplicated_data.dropna(subset=["Giá"])
unduplicated_data.head()
# Out:
#       Price                                            Address   Area  \
# 0   15,2 tỷ  Đường Dương Bá Trạc, Phường 2, Quận 8, Hồ Chí ...  40 m²
# 1    5,6 tỷ  Screc Tower, Đường Trường Sa, Phường 12, Quận ...  90 m²
# 2      7 tỷ  Dự án HaDo Centrosa Garden, Đường 3/2, Phường ...  87 m²
# 3  12,35 tỷ   Đường Nguyễn Trãi, Phường 7, Quận 5, Hồ Chí Minh  60 m²
# 5   1,35 tỷ  Dự án Dream Home Riverside, Đường Nguyễn Văn L...  57 m²
#
#   Bedrooms  Toilets Published At Hướng nhà Hướng ban công           Loại tin  \
# 0  6 phòng  4 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 1  3 phòng  2 phòng   23/10/2024       NaN            NaN         Tin thường
# 2  2 phòng  2 phòng   23/10/2024       NaN            NaN  Tin VIP Kim Cương
# 3  4 phòng      NaN   22/10/2024       NaN            NaN         Tin thường
# 5  2 phòng  2 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
#
#         Status Number of Apartments  \
# 0          NaN                  NaN
# 1  đã bàn giao            60-106 m²
# 2  Đã bàn giao                2.178
# 3          NaN                  NaN
# 5  Đang mở bán             55-75 m²
#
#                                            Developer  Diện Tích    Giá
# 0                                                NaN       40.0  15.20
# 1  Công ty CP Đầu tư Xây dựng và Kinh doanh nhà S...       90.0   5.60
# 2                                     Tập đoàn Hà Đô       87.0   7.00
# 3                                                NaN       60.0  12.35
# 5                       Công ty TNHH SX TM Lý Khương       57.0   1.35

# %%
unduplicated_data["Triệu/m2"] = (unduplicated_data["Giá"] / unduplicated_data["Diện Tích"] * 100).round(1)
unduplicated_data.head(10)
# Out:
#        Price                                            Address    Area  \
# 0    15,2 tỷ  Đường Dương Bá Trạc, Phường 2, Quận 8, Hồ Chí ...   40 m²
# 1     5,6 tỷ  Screc Tower, Đường Trường Sa, Phường 12, Quận ...   90 m²
# 2       7 tỷ  Dự án HaDo Centrosa Garden, Đường 3/2, Phường ...   87 m²
# 3   12,35 tỷ   Đường Nguyễn Trãi, Phường 7, Quận 5, Hồ Chí Minh   60 m²
# 5    1,35 tỷ  Dự án Dream Home Riverside, Đường Nguyễn Văn L...   57 m²
# 6     7,8 tỷ  Đường Phạm Văn Bạch, Phường 15, Tân Bình, Hồ C...  100 m²
# 7    5,95 tỷ  Dự án ICON 56, Đường Bến Vân Đồn, Phường 12, Q...   87 m²
# 9      16 tỷ           Phường Phước Long B, Quận 9, Hồ Chí Minh  156 m²
# 10    8,6 tỷ    Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh   34 m²
# 11    8,7 tỷ  Đường Huỳnh Tấn Phát, Phường Phú Thuận, Quận 7...   80 m²
#
#    Bedrooms  Toilets Published At Hướng nhà Hướng ban công           Loại tin  \
# 0   6 phòng  4 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 1   3 phòng  2 phòng   23/10/2024       NaN            NaN         Tin thường
# 2   2 phòng  2 phòng   23/10/2024       NaN            NaN  Tin VIP Kim Cương
# 3   4 phòng      NaN   22/10/2024       NaN            NaN         Tin thường
# 5   2 phòng  2 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 6   3 phòng  3 phòng   22/10/2024       NaN            NaN         Tin thường
# 7   3 phòng  2 phòng   15/10/2024       NaN            NaN         Tin thường
# 9   8 phòng  9 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 10  3 phòng  4 phòng   22/10/2024       NaN            NaN         Tin thường
# 11  4 phòng  5 phòng   04/10/2024       NaN            NaN         Tin thường
#
#          Status Number of Apartments  \
# 0           NaN                  NaN
# 1   đã bàn giao            60-106 m²
# 2   Đã bàn giao                2.178
# 3           NaN                  NaN
# 5   Đang mở bán             55-75 m²
# 6           NaN                  NaN
# 7   Đã bàn giao            47-112 m²
# 9           NaN                  NaN
# 10          NaN                  NaN
# 11          NaN                  NaN
#
#                                             Developer  Diện Tích    Giá  \
# 0                                                 NaN       40.0  15.20
# 1   Công ty CP Đầu tư Xây dựng và Kinh doanh nhà S...       90.0   5.60
# 2                                      Tập đoàn Hà Đô       87.0   7.00
# 3                                                 NaN       60.0  12.35
# 5                        Công ty TNHH SX TM Lý Khương       57.0   1.35
# 6                                                 NaN      100.0   7.80
# 7                                      Novaland Group       87.0   5.95
# 9                                                 NaN      156.0  16.00
# 10                                                NaN       34.0   8.60
# 11                                                NaN       80.0   8.70
#
#     Triệu/m2
# 0       38.0
# 1        6.2
# 2        8.0
# 3       20.6
# 5        2.4
# 6        7.8
# 7        6.8
# 9       10.3
# 10      25.3
# 11      10.9

# %%
unduplicated_data["Ngày đăng"] = pd.to_datetime(unduplicated_data["Published At"], format="%d/%m/%Y")
unduplicated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11498 entries, 0 to 30359
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Price                 11498 non-null  object
#  1   Address               11498 non-null  object
#  2   Area                  11498 non-null  object
#  3   Bedrooms              7559 non-null   object
#  4   Toilets               7200 non-null   object
#  5   Published At          11498 non-null  object
#  6   Hướng nhà             2956 non-null   object
#  7   Hướng ban công        1723 non-null   object
#  8   Loại tin              11498 non-null  object
#  9   Status                3601 non-null   object
#  10  Number of Apartments  3601 non-null   object
#  11  Developer             3601 non-null   object
#  12  Diện Tích             11498 non-null  float64
#  13  Giá                   11498 non-null  float64
#  14  Triệu/m2              11498 non-null  float64
#  15  Ngày đăng             11498 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(12)
# memory usage: 1.5+ MB

# %%
def convert_the_number_of_rooms(value):
    try:
        if isinstance(value, str):
            if "phòng" in value:
                value = value.replace(" phòng", "")
                return float(value)
            else: return None
        elif isinstance (value, (int, float)):
            return float(value)
        return None
    except Exception as e:
        print(f"Lỗi khi xử lý giá trị {value}, chi tiết lỗi {e}")
        return None
    
unduplicated_data["Số Phòng Ngủ"] = unduplicated_data["Bedrooms"].apply(convert_the_number_of_rooms)
unduplicated_data["Số Nhà Vệ Sinh"] = unduplicated_data["Toilets"].apply(convert_the_number_of_rooms)

# %%
# unduplicated_data.head(10)
unduplicated_data.head(10)
# Out:
#        Price                                            Address    Area  \
# 0    15,2 tỷ  Đường Dương Bá Trạc, Phường 2, Quận 8, Hồ Chí ...   40 m²
# 1     5,6 tỷ  Screc Tower, Đường Trường Sa, Phường 12, Quận ...   90 m²
# 2       7 tỷ  Dự án HaDo Centrosa Garden, Đường 3/2, Phường ...   87 m²
# 3   12,35 tỷ   Đường Nguyễn Trãi, Phường 7, Quận 5, Hồ Chí Minh   60 m²
# 5    1,35 tỷ  Dự án Dream Home Riverside, Đường Nguyễn Văn L...   57 m²
# 6     7,8 tỷ  Đường Phạm Văn Bạch, Phường 15, Tân Bình, Hồ C...  100 m²
# 7    5,95 tỷ  Dự án ICON 56, Đường Bến Vân Đồn, Phường 12, Q...   87 m²
# 9      16 tỷ           Phường Phước Long B, Quận 9, Hồ Chí Minh  156 m²
# 10    8,6 tỷ    Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh   34 m²
# 11    8,7 tỷ  Đường Huỳnh Tấn Phát, Phường Phú Thuận, Quận 7...   80 m²
#
#    Bedrooms  Toilets Published At Hướng nhà Hướng ban công           Loại tin  \
# 0   6 phòng  4 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 1   3 phòng  2 phòng   23/10/2024       NaN            NaN         Tin thường
# 2   2 phòng  2 phòng   23/10/2024       NaN            NaN  Tin VIP Kim Cương
# 3   4 phòng      NaN   22/10/2024       NaN            NaN         Tin thường
# 5   2 phòng  2 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 6   3 phòng  3 phòng   22/10/2024       NaN            NaN         Tin thường
# 7   3 phòng  2 phòng   15/10/2024       NaN            NaN         Tin thường
# 9   8 phòng  9 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 10  3 phòng  4 phòng   22/10/2024       NaN            NaN         Tin thường
# 11  4 phòng  5 phòng   04/10/2024       NaN            NaN         Tin thường
#
#          Status Number of Apartments  \
# 0           NaN                  NaN
# 1   đã bàn giao            60-106 m²
# 2   Đã bàn giao                2.178
# 3           NaN                  NaN
# 5   Đang mở bán             55-75 m²
# 6           NaN                  NaN
# 7   Đã bàn giao            47-112 m²
# 9           NaN                  NaN
# 10          NaN                  NaN
# 11          NaN                  NaN
#
#                                             Developer  Diện Tích    Giá  \
# 0                                                 NaN       40.0  15.20
# 1   Công ty CP Đầu tư Xây dựng và Kinh doanh nhà S...       90.0   5.60
# 2                                      Tập đoàn Hà Đô       87.0   7.00
# 3                                                 NaN       60.0  12.35
# 5                        Công ty TNHH SX TM Lý Khương       57.0   1.35
# 6                                                 NaN      100.0   7.80
# 7                                      Novaland Group       87.0   5.95
# 9                                                 NaN      156.0  16.00
# 10                                                NaN       34.0   8.60
# 11                                                NaN       80.0   8.70
#
#     Triệu/m2  Ngày đăng  Số Phòng Ngủ  Số Nhà Vệ Sinh
# 0       38.0 2024-10-17           6.0             4.0
# 1        6.2 2024-10-23           3.0             2.0
# 2        8.0 2024-10-23           2.0             2.0
# 3       20.6 2024-10-22           4.0             NaN
# 5        2.4 2024-10-17           2.0             2.0
# 6        7.8 2024-10-22           3.0             3.0
# 7        6.8 2024-10-15           3.0             2.0
# 9       10.3 2024-10-17           8.0             9.0
# 10      25.3 2024-10-22           3.0             4.0
# 11      10.9 2024-10-04           4.0             5.0

# %%
# Hàm trích xuất thông tin Đường, Phường, Quận từ address
def extract_info(address):
    # Khởi tạo giá trị mặc định cho Đường, Phường, Quận
    duong, phuong, quan = "Unknown", "Unknown", "Unknown"

    # Tìm kiếm thông tin trong chuỗi địa chỉ
    if "Hồ Chí Minh" in address:
        if "Đường" in address:
            duong = address.split("Đường")[1].split(",")[0].strip()
        if "Phường" in address:
            phuong = address.split("Phường")[1].split(",")[0].strip()
        elif "Xã" in address:
            phuong = address.split("Xã")[1].split(",")[0].strip()
        elif "Thị trấn" in address:
            phuong = address.split("Thị trấn")[1].split(",")[0].strip()

        if "Quận" in address:
            quan = address.split("Quận")[1].split(",")[0].strip()
        elif "Huyện" in address:
            quan = address.split("Huyện")[1].split(",")[0].strip()
        elif "Thủ Đức" in address:
            quan = "Thủ Đức"
        elif "Bình Thạnh" in address:
            quan = "Bình Thạnh"
        elif "Nhà Bè" in address:
            quan = "Nhà Bè"
        elif "Tân Bình" in address:
            quan = "Tân Bình"
        elif "Tân Phú" in address:
            quan = "Tân Phú"
        elif "Phú Nhuận" in address:
            quan = "Phú Nhuận"
        elif "Bình Tân" in address:
            quan = "Bình Tân"

    # Xử lý đường liên phường

    return pd.Series([duong, phuong, quan])

# Áp dụng hàm extract_info và thêm vào 3 cột mới trong DataFrame
unduplicated_data[['Đường', 'Phường', 'Quận']] = unduplicated_data['Address'].apply(extract_info)
unduplicated_data = unduplicated_data[unduplicated_data["Quận"] != "Unknown"]   # Loại bỏ các dữ liệu sai hoặc không thuộc HCM

# Xem kết quả
unduplicated_data.head(10)
# Out:
#        Price                                            Address    Area  \
# 0    15,2 tỷ  Đường Dương Bá Trạc, Phường 2, Quận 8, Hồ Chí ...   40 m²
# 1     5,6 tỷ  Screc Tower, Đường Trường Sa, Phường 12, Quận ...   90 m²
# 2       7 tỷ  Dự án HaDo Centrosa Garden, Đường 3/2, Phường ...   87 m²
# 3   12,35 tỷ   Đường Nguyễn Trãi, Phường 7, Quận 5, Hồ Chí Minh   60 m²
# 5    1,35 tỷ  Dự án Dream Home Riverside, Đường Nguyễn Văn L...   57 m²
# 6     7,8 tỷ  Đường Phạm Văn Bạch, Phường 15, Tân Bình, Hồ C...  100 m²
# 7    5,95 tỷ  Dự án ICON 56, Đường Bến Vân Đồn, Phường 12, Q...   87 m²
# 9      16 tỷ           Phường Phước Long B, Quận 9, Hồ Chí Minh  156 m²
# 10    8,6 tỷ    Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh   34 m²
# 11    8,7 tỷ  Đường Huỳnh Tấn Phát, Phường Phú Thuận, Quận 7...   80 m²
#
#    Bedrooms  Toilets Published At Hướng nhà Hướng ban công           Loại tin  \
# 0   6 phòng  4 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 1   3 phòng  2 phòng   23/10/2024       NaN            NaN         Tin thường
# 2   2 phòng  2 phòng   23/10/2024       NaN            NaN  Tin VIP Kim Cương
# 3   4 phòng      NaN   22/10/2024       NaN            NaN         Tin thường
# 5   2 phòng  2 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 6   3 phòng  3 phòng   22/10/2024       NaN            NaN         Tin thường
# 7   3 phòng  2 phòng   15/10/2024       NaN            NaN         Tin thường
# 9   8 phòng  9 phòng   17/10/2024       NaN            NaN       Tin VIP Bạc
# 10  3 phòng  4 phòng   22/10/2024       NaN            NaN         Tin thường
# 11  4 phòng  5 phòng   04/10/2024       NaN            NaN         Tin thường
#
#          Status  ...                                          Developer  \
# 0           NaN  ...                                                NaN
# 1   đã bàn giao  ...  Công ty CP Đầu tư Xây dựng và Kinh doanh nhà S...
# 2   Đã bàn giao  ...                                     Tập đoàn Hà Đô
# 3           NaN  ...                                                NaN
# 5   Đang mở bán  ...                       Công ty TNHH SX TM Lý Khương
# 6           NaN  ...                                                NaN
# 7   Đã bàn giao  ...                                     Novaland Group
# 9           NaN  ...                                                NaN
# 10          NaN  ...                                                NaN
# 11          NaN  ...                                                NaN
#
#    Diện Tích    Giá  Triệu/m2  Ngày đăng Số Phòng Ngủ  Số Nhà Vệ Sinh  \
# 0       40.0  15.20      38.0 2024-10-17          6.0             4.0
# 1       90.0   5.60       6.2 2024-10-23          3.0             2.0
# 2       87.0   7.00       8.0 2024-10-23          2.0             2.0
# 3       60.0  12.35      20.6 2024-10-22          4.0             NaN
# 5       57.0   1.35       2.4 2024-10-17          2.0             2.0
# 6      100.0   7.80       7.8 2024-10-22          3.0             3.0
# 7       87.0   5.95       6.8 2024-10-15          3.0             2.0
# 9      156.0  16.00      10.3 2024-10-17          8.0             9.0
# 10      34.0   8.60      25.3 2024-10-22          3.0             4.0
# 11      80.0   8.70      10.9 2024-10-04          4.0             5.0
#
#               Đường        Phường      Quận
# 0     Dương Bá Trạc             2         8
# 1         Trường Sa            12         3
# 2               3/2            12        10
# 3       Nguyễn Trãi             7         5
# 5   Nguyễn Văn Linh             7         8
# 6     Phạm Văn Bạch            15  Tân Bình
# 7       Bến Vân Đồn            12         4
# 9           Unknown  Phước Long B         9
# 10        Lê Văn Sỹ            12         3
# 11   Huỳnh Tấn Phát     Phú Thuận         7
#
# [10 rows x 21 columns]

# %%
# Xử lý số lượng các căn hộ
def handle_number_of_apartment(value):
    try:
        if isinstance(value, str):
            value = value.replace(".", "")
            value = int(value)
            return value
        # Nếu value đã là số (float hoặc int), trả về trực tiếp
        elif isinstance(value, (int, float)):
            return float(value)
        
        return None        
    except Exception as e:
        print(f"Lỗi khi xử lý giá trị: {value}. Chi tiết lỗi: {e}")
        return None
    
    

unduplicated_data["Số Căn Hộ"] = unduplicated_data["Number of Apartments"].apply(handle_number_of_apartment)
# Out:
# Lỗi khi xử lý giá trị: 60-106 m². Chi tiết lỗi: invalid literal for int() with base 10: '60-106 m²'
# Lỗi khi xử lý giá trị: 55-75 m². Chi tiết lỗi: invalid literal for int() with base 10: '55-75 m²'
# Lỗi khi xử lý giá trị: 47-112 m². Chi tiết lỗi: invalid literal for int() with base 10: '47-112 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: 44-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '44-95 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 50-100 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-100 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 51-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-95 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 51-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-95 m²'
# Lỗi khi xử lý giá trị: Công ty CP Kiến Á. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Kiến Á'
# Lỗi khi xử lý giá trị: 90-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '90-160 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Thương mại - Xây dựng – Kinh doanh nhà Thanh Nhựt. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Thương mại - Xây dựng – Kinh doanh nhà Thanh Nhựt'
# Lỗi khi xử lý giá trị: 51-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-95 m²'
# Lỗi khi xử lý giá trị: 48-82 m². Chi tiết lỗi: invalid literal for int() with base 10: '48-82 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 101-147 m². Chi tiết lỗi: invalid literal for int() with base 10: '101-147 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: 58 - 115 m². Chi tiết lỗi: invalid literal for int() with base 10: '58 - 115 m²'
# Lỗi khi xử lý giá trị: 53-176 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-176 m²'
# Lỗi khi xử lý giá trị: Công ty Quản lý và Phát triển Nhà Quận 2. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Quản lý và Phát triển Nhà Quận 2'
# Lỗi khi xử lý giá trị: Tập đoàn MIK Corporation. Chi tiết lỗi: invalid literal for int() with base 10: 'Tập đoàn MIK Corporation'
# Lỗi khi xử lý giá trị: 45-300 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-300 m²'
# Lỗi khi xử lý giá trị: Tập đoàn MIK Corporation. Chi tiết lỗi: invalid literal for int() with base 10: 'Tập đoàn MIK Corporation'
# Lỗi khi xử lý giá trị: 52 - 133 m². Chi tiết lỗi: invalid literal for int() with base 10: '52 - 133 m²'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 52 - 133 m². Chi tiết lỗi: invalid literal for int() with base 10: '52 - 133 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Xây dựng và Dịch vụ An Thiên Lý. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Xây dựng và Dịch vụ An Thiên Lý'
# Lỗi khi xử lý giá trị: 72-119 m². Chi tiết lỗi: invalid literal for int() with base 10: '72-119 m²'
# Lỗi khi xử lý giá trị: 63-115 m². Chi tiết lỗi: invalid literal for int() with base 10: '63-115 m²'
# Lỗi khi xử lý giá trị: Novaland Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Novaland Group'
# Lỗi khi xử lý giá trị: Công ty TNHH Xây dựng và Dịch vụ An Thiên Lý. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Xây dựng và Dịch vụ An Thiên Lý'
# Lỗi khi xử lý giá trị: 45-100 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-100 m²'
# Lỗi khi xử lý giá trị: Tổng Công ty CP Đầu tư và Phát triển Địa ốc Khang Gia. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng Công ty CP Đầu tư và Phát triển Địa ốc Khang Gia'
# Lỗi khi xử lý giá trị: Tập đoàn MIK Corporation. Chi tiết lỗi: invalid literal for int() with base 10: 'Tập đoàn MIK Corporation'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: 68-220 m². Chi tiết lỗi: invalid literal for int() with base 10: '68-220 m²'
# Lỗi khi xử lý giá trị: 80-320 m². Chi tiết lỗi: invalid literal for int() with base 10: '80-320 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: 53-93 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-93 m²'
# Lỗi khi xử lý giá trị: 63-92 m². Chi tiết lỗi: invalid literal for int() with base 10: '63-92 m²'
# Lỗi khi xử lý giá trị: 61 - 198 m². Chi tiết lỗi: invalid literal for int() with base 10: '61 - 198 m²'
# Lỗi khi xử lý giá trị: 194-287 m². Chi tiết lỗi: invalid literal for int() with base 10: '194-287 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: 72-297 m². Chi tiết lỗi: invalid literal for int() with base 10: '72-297 m²'
# Lỗi khi xử lý giá trị: 65 - 86 m². Chi tiết lỗi: invalid literal for int() with base 10: '65 - 86 m²'
# Lỗi khi xử lý giá trị: 78-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '78-114 m²'
# Lỗi khi xử lý giá trị: Masterise Homes. Chi tiết lỗi: invalid literal for int() with base 10: 'Masterise Homes'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: 55-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '55-114 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: 51-115 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-115 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: 95 - 124 m². Chi tiết lỗi: invalid literal for int() with base 10: '95 - 124 m²'
# Lỗi khi xử lý giá trị: 83-150 m². Chi tiết lỗi: invalid literal for int() with base 10: '83-150 m²'
# Lỗi khi xử lý giá trị: Tổng công ty Địa ốc Sài Gòn Resco. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng công ty Địa ốc Sài Gòn Resco'
# Lỗi khi xử lý giá trị: 52 - 133 m². Chi tiết lỗi: invalid literal for int() with base 10: '52 - 133 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: 45-100 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-100 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: Tập đoàn MIK Corporation. Chi tiết lỗi: invalid literal for int() with base 10: 'Tập đoàn MIK Corporation'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: Công ty TNHH Xây dựng và Kinh doanh Nhà Điền Phúc Thành. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Xây dựng và Kinh doanh Nhà Điền Phúc Thành'
# Lỗi khi xử lý giá trị: 78-180 m². Chi tiết lỗi: invalid literal for int() with base 10: '78-180 m²'
# Lỗi khi xử lý giá trị: Tập đoàn MIK Corporation. Chi tiết lỗi: invalid literal for int() with base 10: 'Tập đoàn MIK Corporation'
# Lỗi khi xử lý giá trị: 50 - 100 m². Chi tiết lỗi: invalid literal for int() with base 10: '50 - 100 m²'
# Lỗi khi xử lý giá trị: 80-112 m². Chi tiết lỗi: invalid literal for int() with base 10: '80-112 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: 27-120 m². Chi tiết lỗi: invalid literal for int() with base 10: '27-120 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: Công ty CP Bảo Gia. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Bảo Gia'
# Lỗi khi xử lý giá trị: Công ty CP Kiến Á. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Kiến Á'
# Lỗi khi xử lý giá trị: 48-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '48-105 m²'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: 117-130 m². Chi tiết lỗi: invalid literal for int() with base 10: '117-130 m²'
# Lỗi khi xử lý giá trị: 54-81 m². Chi tiết lỗi: invalid literal for int() with base 10: '54-81 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Một thành viên 16. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Một thành viên 16'
# Lỗi khi xử lý giá trị: Masterise Homes. Chi tiết lỗi: invalid literal for int() with base 10: 'Masterise Homes'
# Lỗi khi xử lý giá trị: 45-300 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-300 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: 57-185 m². Chi tiết lỗi: invalid literal for int() with base 10: '57-185 m²'
# Lỗi khi xử lý giá trị: 51-85 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-85 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: 66-180 m². Chi tiết lỗi: invalid literal for int() with base 10: '66-180 m²'
# Lỗi khi xử lý giá trị: 45-100 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-100 m²'
# Lỗi khi xử lý giá trị: 72-119 m². Chi tiết lỗi: invalid literal for int() with base 10: '72-119 m²'
# Lỗi khi xử lý giá trị: 50 - 100 m². Chi tiết lỗi: invalid literal for int() with base 10: '50 - 100 m²'
# Lỗi khi xử lý giá trị: 55-343 m². Chi tiết lỗi: invalid literal for int() with base 10: '55-343 m²'
# Lỗi khi xử lý giá trị: 53-93 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-93 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Gamuda Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Gamuda Land Việt Nam'
# Lỗi khi xử lý giá trị: 50 - 100 m². Chi tiết lỗi: invalid literal for int() with base 10: '50 - 100 m²'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Đại Quang Minh. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Đại Quang Minh'
# Lỗi khi xử lý giá trị: 50 - 100 m². Chi tiết lỗi: invalid literal for int() with base 10: '50 - 100 m²'
# Lỗi khi xử lý giá trị: 57-185 m². Chi tiết lỗi: invalid literal for int() with base 10: '57-185 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: 52-224 m². Chi tiết lỗi: invalid literal for int() with base 10: '52-224 m²'
# Lỗi khi xử lý giá trị: 80-112 m². Chi tiết lỗi: invalid literal for int() with base 10: '80-112 m²'
# Lỗi khi xử lý giá trị: 51-102 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-102 m²'
# Lỗi khi xử lý giá trị: 90-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '90-160 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Gamuda Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Gamuda Land Việt Nam'
# Lỗi khi xử lý giá trị: Công ty TNHH XD TM Dịch vụ Sản xuất Đại Thành. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH XD TM Dịch vụ Sản xuất Đại Thành'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: 45-318 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-318 m²'
# Lỗi khi xử lý giá trị: 51-100 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-100 m²'
# Lỗi khi xử lý giá trị: 50-121 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-121 m²'
# Lỗi khi xử lý giá trị: 49-101 m². Chi tiết lỗi: invalid literal for int() with base 10: '49-101 m²'
# Lỗi khi xử lý giá trị: Masterise Homes. Chi tiết lỗi: invalid literal for int() with base 10: 'Masterise Homes'
# Lỗi khi xử lý giá trị: 49-101 m². Chi tiết lỗi: invalid literal for int() with base 10: '49-101 m²'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: Công ty CP May - Xây dựng Huy Hoàng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP May - Xây dựng Huy Hoàng'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư & Phát triển Xây dựng Investco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư & Phát triển Xây dựng Investco'
# Lỗi khi xử lý giá trị: 68-183 m². Chi tiết lỗi: invalid literal for int() with base 10: '68-183 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: Masterise Homes. Chi tiết lỗi: invalid literal for int() with base 10: 'Masterise Homes'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: 53-93 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-93 m²'
# Lỗi khi xử lý giá trị: 69-372 m². Chi tiết lỗi: invalid literal for int() with base 10: '69-372 m²'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: 51-120 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-120 m²'
# Lỗi khi xử lý giá trị: Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: 56-106 m². Chi tiết lỗi: invalid literal for int() with base 10: '56-106 m²'
# Lỗi khi xử lý giá trị: 27-103 m². Chi tiết lỗi: invalid literal for int() with base 10: '27-103 m²'
# Lỗi khi xử lý giá trị: 44-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '44-95 m²'
# Lỗi khi xử lý giá trị: 50-121 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-121 m²'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: 48-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '48-105 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 58-111 m². Chi tiết lỗi: invalid literal for int() with base 10: '58-111 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: Masterise Homes. Chi tiết lỗi: invalid literal for int() with base 10: 'Masterise Homes'
# Lỗi khi xử lý giá trị: 64-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '64-96 m²'
# Lỗi khi xử lý giá trị: 65 - 86 m². Chi tiết lỗi: invalid literal for int() with base 10: '65 - 86 m²'
# Lỗi khi xử lý giá trị: 73-230 m². Chi tiết lỗi: invalid literal for int() with base 10: '73-230 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thủ Thiêm. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thủ Thiêm'
# Lỗi khi xử lý giá trị: 65 - 86 m². Chi tiết lỗi: invalid literal for int() with base 10: '65 - 86 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 78-180 m². Chi tiết lỗi: invalid literal for int() with base 10: '78-180 m²'
# Lỗi khi xử lý giá trị: 78-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '78-114 m²'
# Lỗi khi xử lý giá trị: 45-100 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-100 m²'
# Lỗi khi xử lý giá trị: 50-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-105 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: 72-119 m². Chi tiết lỗi: invalid literal for int() with base 10: '72-119 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 72-119 m². Chi tiết lỗi: invalid literal for int() with base 10: '72-119 m²'
# Lỗi khi xử lý giá trị: 72-93 m². Chi tiết lỗi: invalid literal for int() with base 10: '72-93 m²'
# Lỗi khi xử lý giá trị: 58-111 m². Chi tiết lỗi: invalid literal for int() with base 10: '58-111 m²'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: Novaland Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Novaland Group'
# Lỗi khi xử lý giá trị: 115-175 m². Chi tiết lỗi: invalid literal for int() with base 10: '115-175 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: 90-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '90-160 m²'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: 48-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '48-105 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương'
# Lỗi khi xử lý giá trị: 55-343 m². Chi tiết lỗi: invalid literal for int() with base 10: '55-343 m²'
# Lỗi khi xử lý giá trị: 45-146 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-146 m²'
# Lỗi khi xử lý giá trị: 69-103 m². Chi tiết lỗi: invalid literal for int() with base 10: '69-103 m²'
# Lỗi khi xử lý giá trị: 45-146 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-146 m²'
# Lỗi khi xử lý giá trị: 101 - 221 m². Chi tiết lỗi: invalid literal for int() with base 10: '101 - 221 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: 45-110 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-110 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Gamuda Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Gamuda Land Việt Nam'
# Lỗi khi xử lý giá trị: 71-92 m². Chi tiết lỗi: invalid literal for int() with base 10: '71-92 m²'
# Lỗi khi xử lý giá trị: 48-122 m². Chi tiết lỗi: invalid literal for int() with base 10: '48-122 m²'
# Lỗi khi xử lý giá trị: 59-218 m². Chi tiết lỗi: invalid literal for int() with base 10: '59-218 m²'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: Công ty GS Engineering & Construction. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty GS Engineering & Construction'
# Lỗi khi xử lý giá trị: 70-152 m². Chi tiết lỗi: invalid literal for int() with base 10: '70-152 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Hưng Phú. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Hưng Phú'
# Lỗi khi xử lý giá trị: 95-143 m². Chi tiết lỗi: invalid literal for int() with base 10: '95-143 m²'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: 90-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '90-160 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Thương mại Dịch vụ Kim Kim Hoàn Mỹ. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Thương mại Dịch vụ Kim Kim Hoàn Mỹ'
# Lỗi khi xử lý giá trị: 66-94 m². Chi tiết lỗi: invalid literal for int() with base 10: '66-94 m²'
# Lỗi khi xử lý giá trị: 50-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-105 m²'
# Lỗi khi xử lý giá trị: 36-58 m². Chi tiết lỗi: invalid literal for int() with base 10: '36-58 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 50-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-105 m²'
# Lỗi khi xử lý giá trị: 45-100 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-100 m²'
# Lỗi khi xử lý giá trị: 50-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-105 m²'
# Lỗi khi xử lý giá trị: Novaland Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Novaland Group'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 68-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '68-98 m²'
# Lỗi khi xử lý giá trị: 122-300 m². Chi tiết lỗi: invalid literal for int() with base 10: '122-300 m²'
# Lỗi khi xử lý giá trị: Công ty Quản lý và Phát triển Nhà Quận 2. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Quản lý và Phát triển Nhà Quận 2'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: 72-119 m². Chi tiết lỗi: invalid literal for int() with base 10: '72-119 m²'
# Lỗi khi xử lý giá trị: 27-103 m². Chi tiết lỗi: invalid literal for int() with base 10: '27-103 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: 50 - 100 m². Chi tiết lỗi: invalid literal for int() with base 10: '50 - 100 m²'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: 51-102 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-102 m²'
# Lỗi khi xử lý giá trị: Công ty CP Hợp tác Kinh tế - XNK Savimex. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Hợp tác Kinh tế - XNK Savimex'
# Lỗi khi xử lý giá trị: 51-80 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-80 m²'
# Lỗi khi xử lý giá trị: 45-146 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-146 m²'
# Lỗi khi xử lý giá trị: 45-100 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-100 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Gamuda Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Gamuda Land Việt Nam'
# Lỗi khi xử lý giá trị: 56-60 m². Chi tiết lỗi: invalid literal for int() with base 10: '56-60 m²'
# Lỗi khi xử lý giá trị: Công ty CP Kỹ thuật Xây dựng Phú Nhuận. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Kỹ thuật Xây dựng Phú Nhuận'
# Lỗi khi xử lý giá trị: 55-343 m². Chi tiết lỗi: invalid literal for int() with base 10: '55-343 m²'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thủ Thiêm. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thủ Thiêm'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: 83-283 m². Chi tiết lỗi: invalid literal for int() with base 10: '83-283 m²'
# Lỗi khi xử lý giá trị: 50-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-105 m²'
# Lỗi khi xử lý giá trị: Tập đoàn Vingroup. Chi tiết lỗi: invalid literal for int() with base 10: 'Tập đoàn Vingroup'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Hưng Phú. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Hưng Phú'
# Lỗi khi xử lý giá trị: 74 - 108 m². Chi tiết lỗi: invalid literal for int() with base 10: '74 - 108 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Nam Long. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Nam Long'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Kiến Á. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Kiến Á'
# Lỗi khi xử lý giá trị: 53 - 110 m². Chi tiết lỗi: invalid literal for int() with base 10: '53 - 110 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: 65 - 86 m². Chi tiết lỗi: invalid literal for int() with base 10: '65 - 86 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: 51-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-95 m²'
# Lỗi khi xử lý giá trị: Masterise Homes. Chi tiết lỗi: invalid literal for int() with base 10: 'Masterise Homes'
# Lỗi khi xử lý giá trị: 73 - 102 m². Chi tiết lỗi: invalid literal for int() with base 10: '73 - 102 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận'
# Lỗi khi xử lý giá trị: Công ty TNHH Một thành viên 16. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Một thành viên 16'
# Lỗi khi xử lý giá trị: 34-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '34-98 m²'
# Lỗi khi xử lý giá trị: 49-101 m². Chi tiết lỗi: invalid literal for int() with base 10: '49-101 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Gamuda Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Gamuda Land Việt Nam'
# Lỗi khi xử lý giá trị: 855-245 m². Chi tiết lỗi: invalid literal for int() with base 10: '855-245 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Gamuda Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Gamuda Land Việt Nam'
# Lỗi khi xử lý giá trị: 57-99 m². Chi tiết lỗi: invalid literal for int() with base 10: '57-99 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: Tổng công ty Địa ốc Sài Gòn Resco. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng công ty Địa ốc Sài Gòn Resco'
# Lỗi khi xử lý giá trị: 50-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-105 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Kiến Á. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Kiến Á'
# Lỗi khi xử lý giá trị: 51-85 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-85 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Nam Long. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Nam Long'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: 51-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-95 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Xây dựng và Dịch vụ An Thiên Lý. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Xây dựng và Dịch vụ An Thiên Lý'
# Lỗi khi xử lý giá trị: Công ty GS Engineering & Construction. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty GS Engineering & Construction'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Địa ốc Sài Gòn. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Địa ốc Sài Gòn'
# Lỗi khi xử lý giá trị: Công ty GS Engineering & Construction. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty GS Engineering & Construction'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Thuỷ Sản Số 4. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Thuỷ Sản Số 4'
# Lỗi khi xử lý giá trị: 51-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-95 m²'
# Lỗi khi xử lý giá trị: Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD'
# Lỗi khi xử lý giá trị: 67-183 m². Chi tiết lỗi: invalid literal for int() with base 10: '67-183 m²'
# Lỗi khi xử lý giá trị: 190-246 m². Chi tiết lỗi: invalid literal for int() with base 10: '190-246 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: 58-111 m². Chi tiết lỗi: invalid literal for int() with base 10: '58-111 m²'
# Lỗi khi xử lý giá trị: 55-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '55-114 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 72-119 m². Chi tiết lỗi: invalid literal for int() with base 10: '72-119 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: Công ty CP Bất động sản Sài Gòn Mới. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Bất động sản Sài Gòn Mới'
# Lỗi khi xử lý giá trị: 57-185 m². Chi tiết lỗi: invalid literal for int() with base 10: '57-185 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: 58-111 m². Chi tiết lỗi: invalid literal for int() with base 10: '58-111 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Nam Long. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Nam Long'
# Lỗi khi xử lý giá trị: Công ty CP Tổ chức Nhà Quốc Gia (NHO). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Tổ chức Nhà Quốc Gia (NHO)'
# Lỗi khi xử lý giá trị: Công ty CP Tập đoàn Hoa Sen. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Tập đoàn Hoa Sen'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: Tập đoàn MIK Corporation. Chi tiết lỗi: invalid literal for int() with base 10: 'Tập đoàn MIK Corporation'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: 53-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-114 m²'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: 855-245 m². Chi tiết lỗi: invalid literal for int() with base 10: '855-245 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương'
# Lỗi khi xử lý giá trị: 101 - 221 m². Chi tiết lỗi: invalid literal for int() with base 10: '101 - 221 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Gamuda Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Gamuda Land Việt Nam'
# Lỗi khi xử lý giá trị: 51-102 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-102 m²'
# Lỗi khi xử lý giá trị: 75-150 m². Chi tiết lỗi: invalid literal for int() with base 10: '75-150 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận'
# Lỗi khi xử lý giá trị: Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: 68-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '68-98 m²'
# Lỗi khi xử lý giá trị: 53-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-114 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 30-300 m². Chi tiết lỗi: invalid literal for int() with base 10: '30-300 m²'
# Lỗi khi xử lý giá trị: 58 - 115 m². Chi tiết lỗi: invalid literal for int() with base 10: '58 - 115 m²'
# Lỗi khi xử lý giá trị: 45-300 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-300 m²'
# Lỗi khi xử lý giá trị: 54-82 m². Chi tiết lỗi: invalid literal for int() with base 10: '54-82 m²'
# Lỗi khi xử lý giá trị: Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng Công ty Đầu tư Phát triển Nhà và Đô thị HUD'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Xây dựng và Kinh doanh Nhà Điền Phúc Thành. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Xây dựng và Kinh doanh Nhà Điền Phúc Thành'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: 52-140 m². Chi tiết lỗi: invalid literal for int() with base 10: '52-140 m²'
# Lỗi khi xử lý giá trị: 855-245 m². Chi tiết lỗi: invalid literal for int() with base 10: '855-245 m²'
# Lỗi khi xử lý giá trị: 90-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '90-160 m²'
# Lỗi khi xử lý giá trị: 82-102 m². Chi tiết lỗi: invalid literal for int() with base 10: '82-102 m²'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: 855-245 m². Chi tiết lỗi: invalid literal for int() with base 10: '855-245 m²'
# Lỗi khi xử lý giá trị: 34-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '34-98 m²'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: 29-81 m². Chi tiết lỗi: invalid literal for int() with base 10: '29-81 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: 50-121 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-121 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: 50 - 100 m². Chi tiết lỗi: invalid literal for int() with base 10: '50 - 100 m²'
# Lỗi khi xử lý giá trị: 34-115 m². Chi tiết lỗi: invalid literal for int() with base 10: '34-115 m²'
# Lỗi khi xử lý giá trị: 49-81 m². Chi tiết lỗi: invalid literal for int() with base 10: '49-81 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Đại Quang Minh. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Đại Quang Minh'
# Lỗi khi xử lý giá trị: 36-58 m². Chi tiết lỗi: invalid literal for int() with base 10: '36-58 m²'
# Lỗi khi xử lý giá trị: Công ty CP Kiến Á. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Kiến Á'
# Lỗi khi xử lý giá trị: 57-79 m². Chi tiết lỗi: invalid literal for int() with base 10: '57-79 m²'
# Lỗi khi xử lý giá trị: 122-300 m². Chi tiết lỗi: invalid literal for int() with base 10: '122-300 m²'
# Lỗi khi xử lý giá trị: 160 - 200 m². Chi tiết lỗi: invalid literal for int() with base 10: '160 - 200 m²'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ Phần Đầu Tư và Kinh Doanh nhà Khang Điền'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Nam Long. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Nam Long'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Nam Long. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Nam Long'
# Lỗi khi xử lý giá trị: 82-102 m². Chi tiết lỗi: invalid literal for int() with base 10: '82-102 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Hưng Phú. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Hưng Phú'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Gamuda Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Gamuda Land Việt Nam'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 56-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '56-114 m²'
# Lỗi khi xử lý giá trị: 55-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '55-114 m²'
# Lỗi khi xử lý giá trị: 27-120 m². Chi tiết lỗi: invalid literal for int() with base 10: '27-120 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Xây dựng và Kinh doanh Nhà Điền Phúc Thành. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Xây dựng và Kinh doanh Nhà Điền Phúc Thành'
# Lỗi khi xử lý giá trị: 65 - 86 m². Chi tiết lỗi: invalid literal for int() with base 10: '65 - 86 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Nam Long. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Nam Long'
# Lỗi khi xử lý giá trị: Công ty CP Xây dựng và Kinh doanh Nhà Kim Sơn. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Xây dựng và Kinh doanh Nhà Kim Sơn'
# Lỗi khi xử lý giá trị: 80-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '80-160 m²'
# Lỗi khi xử lý giá trị: 138 - 177 m². Chi tiết lỗi: invalid literal for int() with base 10: '138 - 177 m²'
# Lỗi khi xử lý giá trị: 44-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '44-95 m²'
# Lỗi khi xử lý giá trị: 69-103 m². Chi tiết lỗi: invalid literal for int() with base 10: '69-103 m²'
# Lỗi khi xử lý giá trị: 78-180 m². Chi tiết lỗi: invalid literal for int() with base 10: '78-180 m²'
# Lỗi khi xử lý giá trị: 55-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '55-114 m²'
# Lỗi khi xử lý giá trị: Tổng công ty Địa ốc Sài Gòn Resco. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng công ty Địa ốc Sài Gòn Resco'
# Lỗi khi xử lý giá trị: 117-130 m². Chi tiết lỗi: invalid literal for int() with base 10: '117-130 m²'
# Lỗi khi xử lý giá trị: 52 - 133 m². Chi tiết lỗi: invalid literal for int() with base 10: '52 - 133 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# ...
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 45 - 90 m². Chi tiết lỗi: invalid literal for int() with base 10: '45 - 90 m²'
# Lỗi khi xử lý giá trị: 68-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '68-98 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 53-166 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-166 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 56-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '56-114 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 57-185 m². Chi tiết lỗi: invalid literal for int() with base 10: '57-185 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: Novaland Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Novaland Group'
# Lỗi khi xử lý giá trị: 50-140 m². Chi tiết lỗi: invalid literal for int() with base 10: '50-140 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH MTV TM - XD - DV- XNK Vĩnh Phong Thái. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH MTV TM - XD - DV- XNK Vĩnh Phong Thái'
# Lỗi khi xử lý giá trị: Công ty CP Phát triển Bất động sản Phát Đạt. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Phát triển Bất động sản Phát Đạt'
# Lỗi khi xử lý giá trị: Tập đoàn MIK Corporation. Chi tiết lỗi: invalid literal for int() with base 10: 'Tập đoàn MIK Corporation'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thủ Thiêm. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thủ Thiêm'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 855-245 m². Chi tiết lỗi: invalid literal for int() with base 10: '855-245 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: Công ty TNHH Phát Triển Phú Mỹ Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Phát Triển Phú Mỹ Hưng'
# Lỗi khi xử lý giá trị: 84-147 m². Chi tiết lỗi: invalid literal for int() with base 10: '84-147 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: Công ty CP Xây dựng và Kinh doanh Nhà Kim Sơn. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Xây dựng và Kinh doanh Nhà Kim Sơn'
# Lỗi khi xử lý giá trị: 29-81 m². Chi tiết lỗi: invalid literal for int() with base 10: '29-81 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Nam Long. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Nam Long'
# Lỗi khi xử lý giá trị: Công ty CP May - Xây dựng Huy Hoàng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP May - Xây dựng Huy Hoàng'
# Lỗi khi xử lý giá trị: Tổng công ty Địa ốc Sài Gòn Resco. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng công ty Địa ốc Sài Gòn Resco'
# Lỗi khi xử lý giá trị: 78-180 m². Chi tiết lỗi: invalid literal for int() with base 10: '78-180 m²'
# Lỗi khi xử lý giá trị: 73-259 m². Chi tiết lỗi: invalid literal for int() with base 10: '73-259 m²'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: 95-168 m². Chi tiết lỗi: invalid literal for int() with base 10: '95-168 m²'
# Lỗi khi xử lý giá trị: 95-168 m². Chi tiết lỗi: invalid literal for int() with base 10: '95-168 m²'
# Lỗi khi xử lý giá trị: 78-180 m². Chi tiết lỗi: invalid literal for int() with base 10: '78-180 m²'
# Lỗi khi xử lý giá trị: 47-112 m². Chi tiết lỗi: invalid literal for int() with base 10: '47-112 m²'
# Lỗi khi xử lý giá trị: 95-168 m². Chi tiết lỗi: invalid literal for int() with base 10: '95-168 m²'
# Lỗi khi xử lý giá trị: 57-185 m². Chi tiết lỗi: invalid literal for int() with base 10: '57-185 m²'
# Lỗi khi xử lý giá trị: 50 - 100 m². Chi tiết lỗi: invalid literal for int() with base 10: '50 - 100 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 51-120 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-120 m²'
# Lỗi khi xử lý giá trị: Công ty CP Vạn Phát Hưng. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Vạn Phát Hưng'
# Lỗi khi xử lý giá trị: Công ty CP Hoàng Anh Gia Lai. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Hoàng Anh Gia Lai'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư & Phát triển Bất động sản An Gia. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư & Phát triển Bất động sản An Gia'
# Lỗi khi xử lý giá trị: 73-259 m². Chi tiết lỗi: invalid literal for int() with base 10: '73-259 m²'
# Lỗi khi xử lý giá trị: 40-75 m². Chi tiết lỗi: invalid literal for int() with base 10: '40-75 m²'
# Lỗi khi xử lý giá trị: 45-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '45-160 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thủ Thiêm. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thủ Thiêm'
# Lỗi khi xử lý giá trị: 27-103 m². Chi tiết lỗi: invalid literal for int() with base 10: '27-103 m²'
# Lỗi khi xử lý giá trị: 51-95 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-95 m²'
# Lỗi khi xử lý giá trị: 51-120 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-120 m²'
# Lỗi khi xử lý giá trị: 78-180 m². Chi tiết lỗi: invalid literal for int() with base 10: '78-180 m²'
# Lỗi khi xử lý giá trị: 78-180 m². Chi tiết lỗi: invalid literal for int() with base 10: '78-180 m²'
# Lỗi khi xử lý giá trị: 70-152 m². Chi tiết lỗi: invalid literal for int() with base 10: '70-152 m²'
# Lỗi khi xử lý giá trị: Tổng công ty Địa ốc Sài Gòn Resco. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng công ty Địa ốc Sài Gòn Resco'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 57-89 m². Chi tiết lỗi: invalid literal for int() with base 10: '57-89 m²'
# Lỗi khi xử lý giá trị: 59-218 m². Chi tiết lỗi: invalid literal for int() with base 10: '59-218 m²'
# Lỗi khi xử lý giá trị: Công ty CP Bất động sản Sài Gòn Mới. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Bất động sản Sài Gòn Mới'
# Lỗi khi xử lý giá trị: Tổng Công ty CP Đầu tư và Phát triển Địa ốc Khang Gia. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng Công ty CP Đầu tư và Phát triển Địa ốc Khang Gia'
# Lỗi khi xử lý giá trị: 56-162 m². Chi tiết lỗi: invalid literal for int() with base 10: '56-162 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư & Phát triển Bất động sản An Gia. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư & Phát triển Bất động sản An Gia'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư & Phát triển Xây dựng Investco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư & Phát triển Xây dựng Investco'
# Lỗi khi xử lý giá trị: Công ty TNHH Xây dựng Kinh doanh nhà Tân Thành Lập. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Xây dựng Kinh doanh nhà Tân Thành Lập'
# Lỗi khi xử lý giá trị: Tổng công ty Địa ốc Sài Gòn Resco. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng công ty Địa ốc Sài Gòn Resco'
# Lỗi khi xử lý giá trị: Công ty CP Kiến Á. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Kiến Á'
# Lỗi khi xử lý giá trị: 27-120 m². Chi tiết lỗi: invalid literal for int() with base 10: '27-120 m²'
# Lỗi khi xử lý giá trị: 53-114 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-114 m²'
# Lỗi khi xử lý giá trị: 74 - 108 m². Chi tiết lỗi: invalid literal for int() with base 10: '74 - 108 m²'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: 90-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '90-160 m²'
# Lỗi khi xử lý giá trị: 29-81 m². Chi tiết lỗi: invalid literal for int() with base 10: '29-81 m²'
# Lỗi khi xử lý giá trị: 51-102 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-102 m²'
# Lỗi khi xử lý giá trị: 38-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '38-98 m²'
# Lỗi khi xử lý giá trị: 90-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '90-160 m²'
# Lỗi khi xử lý giá trị: 90-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '90-160 m²'
# Lỗi khi xử lý giá trị: 90-160 m². Chi tiết lỗi: invalid literal for int() with base 10: '90-160 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: 53-176 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-176 m²'
# Lỗi khi xử lý giá trị: Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land). Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Địa ốc Sài Gòn Thương Tín (TTC Land)'
# Lỗi khi xử lý giá trị: 51-120 m². Chi tiết lỗi: invalid literal for int() with base 10: '51-120 m²'
# Lỗi khi xử lý giá trị: 53-96 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-96 m²'
# Lỗi khi xử lý giá trị: 300-415 m². Chi tiết lỗi: invalid literal for int() with base 10: '300-415 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: 300-415 m². Chi tiết lỗi: invalid literal for int() with base 10: '300-415 m²'
# Lỗi khi xử lý giá trị: 300-415 m². Chi tiết lỗi: invalid literal for int() with base 10: '300-415 m²'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Gamuda Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Gamuda Land Việt Nam'
# Lỗi khi xử lý giá trị: Công ty Quản lý và Phát triển Nhà Quận 2. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Quản lý và Phát triển Nhà Quận 2'
# Lỗi khi xử lý giá trị: 101 - 221 m². Chi tiết lỗi: invalid literal for int() with base 10: '101 - 221 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương'
# Lỗi khi xử lý giá trị: Công ty TNHH Keppel Land Việt Nam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH Keppel Land Việt Nam'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: 855-245 m². Chi tiết lỗi: invalid literal for int() with base 10: '855-245 m²'
# Lỗi khi xử lý giá trị: Đang cập nhật. Chi tiết lỗi: invalid literal for int() with base 10: 'Đang cập nhật'
# Lỗi khi xử lý giá trị: 79-2705 m². Chi tiết lỗi: invalid literal for int() with base 10: '79-2705 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Thương mại Dịch vụ Địa ôc Thái Dương'
# Lỗi khi xử lý giá trị: Công ty CP Xây dựng và Kinh doanh Nhà Kim Sơn. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Xây dựng và Kinh doanh Nhà Kim Sơn'
# Lỗi khi xử lý giá trị: Công ty Cổ phần Him Lam. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty Cổ phần Him Lam'
# Lỗi khi xử lý giá trị: 55-144 m². Chi tiết lỗi: invalid literal for int() with base 10: '55-144 m²'
# Lỗi khi xử lý giá trị: Công ty CP Hoàng Anh Gia Lai. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Hoàng Anh Gia Lai'
# Lỗi khi xử lý giá trị: 855-245 m². Chi tiết lỗi: invalid literal for int() with base 10: '855-245 m²'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư và Dịch vụ TpHCM - Invesco'
# Lỗi khi xử lý giá trị: 855-245 m². Chi tiết lỗi: invalid literal for int() with base 10: '855-245 m²'
# Lỗi khi xử lý giá trị: Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận'
# Lỗi khi xử lý giá trị: 53-86 m². Chi tiết lỗi: invalid literal for int() with base 10: '53-86 m²'
# Lỗi khi xử lý giá trị: Tổng công ty Địa ốc Sài Gòn Resco. Chi tiết lỗi: invalid literal for int() with base 10: 'Tổng công ty Địa ốc Sài Gòn Resco'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty TNHH MTV Xây dựng và Kinh doanh Nhà Phú Nhuận'
# Lỗi khi xử lý giá trị: 66-105 m². Chi tiết lỗi: invalid literal for int() with base 10: '66-105 m²'
# Lỗi khi xử lý giá trị: 68-98 m². Chi tiết lỗi: invalid literal for int() with base 10: '68-98 m²'
# Lỗi khi xử lý giá trị: 27-103 m². Chi tiết lỗi: invalid literal for int() with base 10: '27-103 m²'
# Lỗi khi xử lý giá trị: Novaland Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Novaland Group'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'
# Lỗi khi xử lý giá trị: Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group. Chi tiết lỗi: invalid literal for int() with base 10: 'Công ty CP Đầu tư Địa ốc Vạn Phúc - Dai Phuc Group'

# %%
unduplicated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9257 entries, 0 to 30359
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Price                 9257 non-null   object
#  1   Address               9257 non-null   object
#  2   Area                  9257 non-null   object
#  3   Bedrooms              6333 non-null   object
#  4   Toilets               6049 non-null   object
#  5   Published At          9257 non-null   object
#  6   Hướng nhà             2355 non-null   object
#  7   Hướng ban công        1404 non-null   object
#  8   Loại tin              9257 non-null   object
#  9   Status                3005 non-null   object
#  10  Number of Apartments  3005 non-null   object
#  11  Developer             3005 non-null   object
#  12  Diện Tích             9257 non-null   float64
#  13  Giá                   9257 non-null   float64
#  14  Triệu/m2              9257 non-null   float64
#  15  Ngày đăng             9257 non-null   datetime64[ns]
#  16  Số Phòng Ngủ          6333 non-null   float64
#  17  Số Nhà Vệ Sinh        6049 non-null   float64
#  18  Đường                 9257 non-null   object
#  19  Phường                9257 non-null   object
#  20  Quận                  9257 non-null   object
#  21  Số Căn Hộ             934 non-null    float64
# dtypes: datetime64[ns](1), float64(6), object(15)
# memory usage: 1.6+ MB

# %%
unduplicated_data.describe()
# Out:
#           Diện Tích          Giá     Triệu/m2                      Ngày đăng  \
# count   9257.000000  9257.000000  9257.000000                           9257
# mean     159.460178    23.055166    14.703619  2024-10-23 08:33:11.141838592
# min        7.000000     0.003890     0.000000            2024-09-27 00:00:00
# 25%       64.000000     4.650000     6.100000            2024-10-23 00:00:00
# 50%       88.000000     9.200000    10.400000            2024-10-24 00:00:00
# 75%      141.000000    22.000000    18.000000            2024-10-26 00:00:00
# max    30000.000000   900.000000   880.000000            2024-10-31 00:00:00
# std      572.244035    49.314856    18.016806                            NaN
#
#        Số Phòng Ngủ  Số Nhà Vệ Sinh     Số Căn Hộ
# count   6333.000000     6049.000000    934.000000
# mean       4.053687        3.824599   1980.153105
# min        1.000000        1.000000      2.000000
# 25%        2.000000        2.000000    437.000000
# 50%        3.000000        3.000000    900.000000
# 75%        4.000000        5.000000   1780.000000
# max      200.000000       96.000000  13000.000000
# std        5.551057        4.502918   3184.268993

# %% [markdown]
# Có các oulier tại cột price như 900 tỷ, cột area như 30,000 tỷ, bedroom 200 phòng, 96 toilet --> không phải dự án bất động sản riêng lẻ --> chuỗi dự án căn hộ cấp cao? --> Loại bỏ

# %%
# Code xử lý loại bỏ các ngoại lai quá lớn có thể ảnh hưởng đến dữ liệu
# Tính Q1, Q3 và IQR của cột Giá
Q1_price = unduplicated_data['Giá'].quantile(0.25)
Q3_price = unduplicated_data['Giá'].quantile(0.75)
IQR_price = Q3_price - Q1_price

# Tính Q1, Q3 và IQR của cột Diện Tích
Q1_area = unduplicated_data['Diện Tích'].quantile(0.25)
Q3_area = unduplicated_data['Diện Tích'].quantile(0.75)
IQR_area = Q3_area - Q1_area


# Lọc các giá trị không phải là ngoại lai
df_no_outliers = unduplicated_data[(unduplicated_data['Diện Tích'] >= Q1_area - 1.5 * IQR_area) & (unduplicated_data['Diện Tích'] <= Q3_area + 1.5 * IQR_area)]
df_no_outliers = df_no_outliers[(df_no_outliers['Giá'] >= Q1_price - 1.5 * IQR_price) & (df_no_outliers['Giá'] <= Q3_price + 1.5 * IQR_price)]

# %%
# Việt hóa
unduplicated_data["Chủ Đầu Tư"] = unduplicated_data["Developer"]
unduplicated_data["Trạng Thái"] = unduplicated_data["Status"]

# %%
# Drop các cột dư thừa sau khi Việt hóa
unduplicated_data = unduplicated_data.drop(["Area", "Price", "Address", "Bedrooms", "Toilets", "Published At", "Developer", "Status", "Number of Apartments"], axis="columns")

# %%
unduplicated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9257 entries, 0 to 30359
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hướng nhà       2355 non-null   object
#  1   Hướng ban công  1404 non-null   object
#  2   Loại tin        9257 non-null   object
#  3   Diện Tích       9257 non-null   float64
#  4   Giá             9257 non-null   float64
#  5   Triệu/m2        9257 non-null   float64
#  6   Ngày đăng       9257 non-null   datetime64[ns]
#  7   Số Phòng Ngủ    6333 non-null   float64
#  8   Số Nhà Vệ Sinh  6049 non-null   float64
#  9   Đường           9257 non-null   object
#  10  Phường          9257 non-null   object
#  11  Quận            9257 non-null   object
#  12  Số Căn Hộ       934 non-null    float64
#  13  Chủ Đầu Tư      3005 non-null   object
#  14  Trạng Thái      3005 non-null   object
# dtypes: datetime64[ns](1), float64(6), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ## THỐNG KÊ SỐ LƯỢNG BDS MỖI QUẬN, HUYỆN

# %%
# Đếm số lượng BĐS trong mỗi quận
district_counts = unduplicated_data['Quận'].value_counts().reset_index()
district_counts.columns = ['Quận', 'Số lượng BĐS']

# Vẽ biểu đồ với seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=district_counts, x='Quận', y='Số lượng BĐS', palette='viridis')
plt.title('Số lượng BĐS ở mỗi quận')
plt.xlabel('Quận')
plt.ylabel('Số lượng BĐS')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lehoa\AppData\Local\Temp\ipykernel_36248\1028449840.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=district_counts, x='Quận', y='Số lượng BĐS', palette='viridis')

# %% [markdown]
# ## SỰ PHÂN BỔ VỀ GIÁ TRỊ BDS

# %%
# Vẽ biểu đồ với seaborn
plt.figure(figsize=(10, 6))
sns.histplot(data=df_no_outliers, x="Giá", bins=40, kde=True)
plt.title('Sự phân bổ giá trị BDS tại thành phố Hồ Chí Minh')
plt.xlabel('Giá trị (tỷ VND)')
plt.ylabel('Số lượng BĐS')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## SỰ LIÊN HỆ GIỮA GIÁ TRỊ VÀ DIỆN TÍCH BDS TẠI TPHCM

# %%
# Vẽ biểu đồ với seaborn
plt.figure(figsize=(10, 6))
sns.regplot(data=df_no_outliers, x=df_no_outliers["Diện Tích"], y=df_no_outliers["Giá"])
plt.title('Sự liên hệ giữa Giá trị và Diện tích BDS tại thành phố Hồ Chí Minh')
plt.xlabel('Diện tích (m2)')
plt.ylabel('Giá (tỷ VND)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Nhận xét:
# - Giá và Diện tích của BDS có tính tương quan thuận với nhau.
# - Biểu đồ cho thấy sự phân tán lớn chứng tỏ giá bất động sản ở mỗi khu vực khác nhau có sự khác biệt lớn.

# %% [markdown]
# ## Sự liên hệ giữa Giá và Diện tích BDS tại một số quận ở thành phố Hồ Chí Minh

# %%
# Rút trích dữ liệu của một số quận để Visualization 
district_2 = df_no_outliers[df_no_outliers["Quận"] == "2"]
district_7 = df_no_outliers[df_no_outliers["Quận"] == "7"]
district_9 = df_no_outliers[df_no_outliers["Quận"] == "9"]
district_BinhThanh = df_no_outliers[df_no_outliers["Quận"] == "Bình Thạnh"]

# %%
datasets = [district_2, district_7, district_9, district_BinhThanh]
district_names = ["Quận 2", "Quận 7", "Quận 9", "Quận Bình Thạnh"]
n_rows = 2
n_cols = 2

fig, ax = plt.subplots(n_rows, n_cols, figsize = (n_cols * 4, n_rows * 4))

for r in range(n_rows):
    for c in range(n_cols):
        i = r *  n_cols + c
        if i < len(datasets):
            ax_i = ax[r, c]
            sns.regplot(data=datasets[i], x=datasets[i]["Diện Tích"], y=datasets[i]["Giá"], ax=ax_i)
            ax_i.set_title(f"Biểu đồ {i + 1}: {district_names[i]}")
plt.tight_layout()
plt.show()

# %%
num_devs = unduplicated_data["Chủ Đầu Tư"].nunique()
num_devs
# Out:
# 189

# %% [markdown]
# #### Có tổng số 189 nhà đầu tư BDS khác nhau trong tập dữ liệu

# %% [markdown]
# ## Khu vực nào được đăng bán nhiều nhất

# %%
# Đếm số lượng BĐS trong mỗi quận
district_counts = unduplicated_data['Quận'].value_counts().reset_index()
district_counts.columns = ['Quận', 'Số lượng BĐS']

# Vẽ biểu đồ với seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=district_counts, x='Quận', y='Số lượng BĐS', palette='viridis')
plt.title('Số lượng BĐS được đăng bán ở mỗi Quận')
plt.xlabel('Quận')
plt.ylabel('Số lượng BĐS')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lehoa\AppData\Local\Temp\ipykernel_36248\71674951.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=district_counts, x='Quận', y='Số lượng BĐS', palette='viridis')

# %% [markdown]
# ## Mức giá trung bình nào thì đăng bán nhiều nhất

# %%
# Các khoảng giá
bins = [1, 10, 20, 30, 40, 50, 60, 70, 80]  
labels = ['1-10', '11-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80']

# Thêm cột khoảng giá vào DataFrame
unduplicated_data['Khoảng giá'] = pd.cut(unduplicated_data['Giá'], bins=bins, labels=labels, include_lowest=True)


# Đếm số lượng bất động sản theo khoảng giá
price_range_counts = unduplicated_data['Khoảng giá'].value_counts().reset_index()
price_range_counts.columns = ['Khoảng giá', 'Số lượng BĐS']

# Sắp xếp lại thứ tự khoảng giá theo bins
price_range_counts['Khoảng giá'] = pd.Categorical(price_range_counts['Khoảng giá'], categories=labels, ordered=True)
price_range_counts = price_range_counts.sort_values('Khoảng giá')

# Vẽ biểu đồ với seaborn
plt.figure(figsize=(12, 8))
sns.barplot(data=price_range_counts, x='Khoảng giá', y='Số lượng BĐS', palette='viridis')
plt.title('Số lượng bất động sản trong từng khoảng giá')
plt.xlabel('Khoảng giá (tỷ VND)')
plt.ylabel('Số lượng BĐS')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lehoa\AppData\Local\Temp\ipykernel_36248\1451803660.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=price_range_counts, x='Khoảng giá', y='Số lượng BĐS', palette='viridis')

# %% [markdown]
# ## Khu vực nào có mức giá trung bình cao nhất

# %%
# Tính giá trung bình của mõi quận
district_avg_price = unduplicated_data.groupby('Quận')['Giá'].mean().reset_index()
district_avg_price.columns = ['Quận', 'Giá trung bình']
district_avg_price = district_avg_price.sort_values(by='Giá trung bình', ascending=False)

# Vẽ biểu đồ với seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=district_avg_price, x='Quận', y='Giá trung bình', palette='viridis')
plt.title('Giá trung bình bất động sản ở mỗi Quận')
plt.xlabel('Quận')
plt.ylabel('Giá trung bình (VND)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lehoa\AppData\Local\Temp\ipykernel_36248\3005337849.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=district_avg_price, x='Quận', y='Giá trung bình', palette='viridis')

# %% [markdown]
# ## Số lượng phòng cao hơn có đồng nghĩa với việc bất động sản có giá cao hơn

# %%
# Các khoảng số phòng
bins = [0, 1, 2, 3, 4, 5, float('inf')]
labels = ['1', '2', '3', '4', '5', '5+']

# Thêm cột 'Khoảng số phòng' vào DataFrame
unduplicated_data['Khoảng số phòng'] = pd.cut(unduplicated_data['Số Phòng Ngủ'], bins=bins, labels=labels, include_lowest=True)

# Tính giá trung bình của mỗi khoảng số phòng
room_avg_price = unduplicated_data.groupby('Khoảng số phòng')['Giá'].mean().reset_index()
room_avg_price.columns = ['Khoảng số phòng', 'Giá trung bình']

# Vẽ biểu đồ với seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=room_avg_price, x='Khoảng số phòng', y='Giá trung bình', palette='viridis')
plt.title('Giá trung bình bất động sản theo số phòng')
plt.xlabel('Số phòng')
plt.ylabel('Giá trung bình (tỷ VND)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lehoa\AppData\Local\Temp\ipykernel_36248\1730464839.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   room_avg_price = unduplicated_data.groupby('Khoảng số phòng')['Giá'].mean().reset_index()
# C:\Users\lehoa\AppData\Local\Temp\ipykernel_36248\1730464839.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=room_avg_price, x='Khoảng số phòng', y='Giá trung bình', palette='viridis')
